# %%
import os
import sys
import torch
import matplotlib.pyplot as plt
import numpy as np

# src 폴더를 경로에 추가 (interp_loader를 불러오기 위함)
sys.path.append('../')
from .constants import *

# 경로 설정
BASE_DIR = ".."
CSV_PATH = os.path.join(BASE_DIR, 'rawData', 'water_quality_training_dataset.csv')
CHIP_DIR = os.path.join(BASE_DIR, 'rawData', 'chips')

# 데이터셋 인스턴스 생성
dataset = InterpWaterDataset(CSV_PATH, CHIP_DIR)

print(f"매칭된 총 샘플 수: {len(dataset)}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 # src 폴더를 경로에 추가 (interp_loader를 불러오기 위함)
#       8 sys.path.append('../')
# ----> 9 from src.interp_loader import InterpWaterDataset
#      11 # 경로 설정
#      12 BASE_DIR = ".."
#
# File ~/EY_Water_Challenge_2026/notebooks/../src/interp_loader.py:9
#       7 import torch
#       8 from torch.utils.data import Dataset
# ----> 9 from src.constants import * # 방금 만든 상수 파일 임포트
#      11 class InterpWaterDataset(Dataset):
#      12     def __init__(self, csv_path, chips_dir, mode='train'):
#
# ModuleNotFoundError: No module named 'src.constants'
